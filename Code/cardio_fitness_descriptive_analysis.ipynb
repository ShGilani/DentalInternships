# %% [markdown]
# # Cardio Fitness Products - Descriptive Analysis

# %%
import seaborn as sns

# %%
df=pd.read_csv("CardioGoodFitness.csv")
df.head(3)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66

# %%
df.describe()
# Out:
#               Age      Gender   Education  MaritalStatus       Usage  \
# count  180.000000  180.000000  180.000000     180.000000  180.000000
# mean    28.788889    1.422222   15.572222       1.594444    3.455556
# std      6.943498    0.495291    1.617055       0.492369    1.084797
# min     18.000000    1.000000   12.000000       1.000000    2.000000
# 25%     24.000000    1.000000   14.000000       1.000000    3.000000
# 50%     26.000000    1.000000   16.000000       2.000000    3.000000
# 75%     33.000000    2.000000   16.000000       2.000000    4.000000
# max     50.000000    2.000000   21.000000       2.000000    7.000000
#
#           Fitness         Income       Miles
# count  180.000000     180.000000  180.000000
# mean     3.311111   53719.577778  103.194444
# std      0.958869   16506.684226   51.863605
# min      1.000000   29562.000000   21.000000
# 25%      3.000000   44058.750000   66.000000
# 50%      3.000000   50596.500000   94.000000
# ...

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
#for categorical data to be converted to numerical field

df["MaritalStatus"]=df["MaritalStatus"].replace("Single",1)
df["MaritalStatus"]=df["MaritalStatus"].replace("Partnered",2)

df["Gender"]=df["Gender"].replace("Male",1)
df["Gender"]=df["Gender"].replace("Female",2)

#after conversion
df.head(3)
# Out:
#   Product  Age  Gender  Education  MaritalStatus  Usage  Fitness  Income  \
# 0   TM195   18       1         14              1      3        4   29562
# 1   TM195   19       1         15              1      2        3   31836
# 2   TM195   19       2         14              2      4        3   30699
#
#    Miles
# 0    112
# 1     75
# 2     66

# %%
sns.countplot(x="Gender", data=df)

# %%
# Gender wise Data Distribution (Pie Chart)

# %%
sns.countplot(x="MaritalStatus", data=df)
#sns.countplot(x="MaritalStatus", hue="Gender", data=df)

# %%
#findout unique values of Class column of Data Set

df["Product"].unique() 

sns.countplot(x="Product", data=df)

#TM798 could be a high end product

# %%
#sns.countplot(x="Product", hue="MaritalStatus", data=df)
sns.countplot(x="Product", hue="Gender", data=df)

#TM798 is largely bought by Married Male

# %%
sns.boxplot(x="Age", data=df)

# %%
sns.boxplot(x="Usage", data=df)

# %%
sns.boxplot(x="Usage", hue="Age",data=df)

# %%
sns.boxplot(x="Product", y="Usage", hue="Gender", data=df)

# females have more usage of TM798.

# %%
sns.boxplot(x="Product", y="Usage", hue="MaritalStatus", data=df)
# Partenered have more usage of TM798.

# %%
sns.boxplot(x="Age", y="Product", hue="Gender", data=df)

#Min and Max age at which TM798 is bought is higher than that for others products

# %%
sns.boxplot(x="Fitness", y="Miles", data=df)

# %%
sns.boxplot(x="Product", y="Fitness",data=df)

# More fit people ( having 4 to 5 fitness level) chose TM798

# %%
sns.boxplot(x="Product", y="Usage",data=df)

# %%
sns.boxplot(x="Product", y="Income",data=df)

#If the income is falling below 50k, generally product1 is opted. We can recommed them product2
# TM798 is expensive, can be afforded by 60k+
# Can recommed TM798 to ppl with Income betweene 50k to 70k (who go for P1/P2)

# %%
sns.boxplot(x="Product", y="Income", hue="Gender",data=df)

# %%
sns.boxplot(x="Product", y="Education",data=df)
#Educated go for P3

# %%
df["Product"]=df["Product"].replace("TM195",195)
df["Product"]=df["Product"].replace("TM498",498)
df["Product"]=df["Product"].replace("TM798",798)

# %%
#PAIR PLOT

sns.pairplot(df)
